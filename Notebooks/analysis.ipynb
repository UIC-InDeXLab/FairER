# %% [markdown]
# # Fair Entity Matching

# %% [markdown]
# ## Requirements
# Before running the cell below, make sure that you have docker properly installed with non-root user permissions,
# make sure you have an NVIDIA GPU available and docker has access to GPU.

# %% [markdown]
# ## Generating Ditto Predictions

# %% [markdown]
# Change the `EPOCHS` environment variable to your preference

# %%
# !docker run --gpus all -e EPOCHS=1 -v ./ditto_results/:/app/ditto/results neemashahbazi/fair-entity-matching:ditto-0.1.2
# Out:
# Starting training process ...
# Executing docker-entrypoint.sh in ditto
# Starting ditto training ...
# Running task Cameras ...
# ...
# /opt/conda/lib/python3.7/site-packages/spacy/pipeline/lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# ...
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_transform.bias', 'vocab_layer_norm.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# ## Generating GNEM Predictions

# %%
# !docker run --gpus all -e EPOCHS=1 -v ./gnem_results/:/app/GNEM/results neemashahbazi/fair-entity-matching:gnem-0.1.3
# Out:
# Unable to find image 'neemashahbazi/fair-entity-matching:gnem-0.1.1' locally
# gnem-0.1.1: Pulling from neemashahbazi/fair-entity-matching
#
# 490126ef: Pulling fs layer
# 756bea58: Pulling fs layer
# 0840847c: Pulling fs layer
# b700ef54: Pulling fs layer
# 862a3134: Pulling fs layer
# 5ffe37a4: Pulling fs layer
# 8ff26b18: Pulling fs layer
# 1f95bafe: Pulling fs layer
# 79a106d2: Pulling fs layer
# 22f27b66: Pulling fs layer
# 7101b30c: Pulling fs layer
# cef4a291: Pulling fs layer
# 904cf261: Pulling fs layer
# ad600853: Pulling fs layer
# 4f410424: Pulling fs layer
# 8e8d0014: Pull complete 1.6kB/11.6kBBBExtracting  1.558GB/3.429GBExtracting  2.207GB/3.429GBDigest: sha256:08abaf1bfc2647336fec62555ff757f23c1c8f0763fbd37ccfb595886da54f77
# Status: Downloaded newer image for neemashahbazi/fair-entity-matching:gnem-0.1.1
# Starting training process ...
# Executing docker-entrypoint.sh in GNEM
# Starting GNEM training ...
# Running task Cameras ...
# ...

# %% [markdown]
# ## Generating DeepMatcher Predictions

# %%
# !docker run --gpus all -e EPOCHS=1 -v ./deepmatcher_results/:/app/deepmatcher/results neemashahbazi/fair-entity-matching:deepmatcher-0.1.1
# Out:
# Starting training process ...
# Executing docker-entrypoint.sh in deepmatcher
# ...
# 2024-02-20 23:51:14 URL:https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.en.zip [10356881291/10356881291] -> "/root/.vector_cache/wiki.en.zip" [1]
# Archive:  /root/.vector_cache/wiki.en.zip
#   inflating: /root/.vector_cache/wiki.en.vec
#   inflating: /root/.vector_cache/wiki.en.bin
# wiki.en.bin
# wiki.en.vec
# wiki.en.zip
# Starting deepmatcher training ...
# Running task Cameras ...
# ...
# * Number of trainable parameters: 5056204
# ===>  TRAIN Epoch 1
# ...
# /opt/conda/lib/python3.7/site-packages/torch/nn/modules/module.py:949: UserWarning: Using non-full backward hooks on a Module that does not take as input a single Tensor or a tuple of Tensors is deprecated and will be removed in future versions. This hook will be missing some of the grad_input. Please use register_full_backward_hook to get the documented behavior.
# ...

# %% [markdown]
# ## Generating HierMatcher Predictions

# %%
# !docker run --gpus all -e EPOCHS=1 -v ./hiermatcher_results/:/app/HierMatcher/results neemashahbazi/fair-entity-matching:hiermatcher-0.1.1
# Out:
# Starting training process ...
# Executing docker-entrypoint.sh in HierMatcher
# ...
# 2024-02-22 18:56:48 URL:https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.en.zip [10356881291/10356881291] -> "embedding/wiki.en.zip" [1]
# Archive:  embedding/wiki.en.zip
#   inflating: ./embedding/wiki.en.vec
#   inflating: ./embedding/wiki.en.bin
# Starting HierMatcher training ...
# Running task Cameras ...
# model_name: HierMatcher
# dataset_dir: data/Cameras
# embedding_dir: embedding/
# epochs: 1
# task: Cameras
# ...
# hidden_size =  70
# embedding_length =  300
# manualSeed =  2
# * Number of trainable parameters: 1073944
# ===>  TRAIN Epoch 1
# ...
# /app/HierMatcher/model/HierMatcher.py:130: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(field_embedding_left, gain=nn.init.calculate_gain('relu'))
# ...

# %% [markdown]
# ## Generating MCAN Predictions

# %%
# !docker run -e EPOCHS=1 -v ./mcan_results/:/app/MCAN/results neemashahbazi/fair-entity-matching:mcan-0.1.1
# Out:
# Starting training process ...
# Executing docker-entrypoint.sh in MCAN
# ...
# 2024-02-22 18:09:06 URL:https://dl.fbaipublicfiles.com/fasttext/vectors-wiki/wiki.en.zip [10356881291/10356881291] -> "data/wiki.en.zip" [1]
# Archive:  data/wiki.en.zip
#   inflating: ./data/wiki.en.vec
#   inflating: ./data/wiki.en.bin
# Starting MCAN training ...
# Running task Compas ...
# ...
# * Number of trainable parameters: 6225605
# ===>  TRAIN Epoch 1
# ...
# Finished Epoch 1 || Run Time:  180.6 | Load Time:    1.3 || F1:  21.69 | Prec:  47.37 | Rec:  14.06 || Ex/s: 110.06
#
# ===>  TEST Epoch 1
# ...

# %% [markdown]
# ## Generating Non-neural Predictions

# %%
# !docker run -e EPOCHS=1 -v ./nonneural_results/:/app/non-neural/results neemashahbazi/fair-entity-matching:nonneural-0.1.3
# Out:
# Starting training process ...
# Executing docker-entrypoint.sh in non-neural
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# 0                    label_label_exm
# 1                    label_label_anm
# 2               label_label_lev_dist
# 3                label_label_lev_sim
# 4                          id_id_exm
# 5                          id_id_anm
# 6                     id_id_lev_dist
# 7                      id_id_lev_sim
# 8        title_title_jac_qgm_3_qgm_3
# 9    title_title_cos_dlm_dc0_dlm_dc0
# Name: feature_name, dtype: object
# ...

# %%
# !mv nonneural_results/* ./
# Out:
# [sudo] password for nima:
