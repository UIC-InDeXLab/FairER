# %%
# !python experiments.py Compas Ethnic_Code_Text 0.05 [6,12]
# Out:
# =============== Compas ===============
# Model: DeepMatcher
# accuracy 0.9943014657160275
# f1 0.0
# /home/nima/fairER/Notebooks/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# precision 0.0 ,  recall 0.0
# workload TP FP TN FN (0, 0, 75028, 430)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.9955008799017167, 0.9970447195271551]
# Disparity Values: [0.0011994141856891405, 0.0027432538111276106]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# statistical_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [0.9955008799017167, 0.9970447195271551]
# Disparity Values: [0.0011994141856891405, 0.0027432538111276106]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (0, 0, 59963, 271)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (0, 0, 53643, 159)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [1, 1]
# Disparity Values: [0, 0]
# ---------------------
# -------------------------------------------------
# Model: HierMatcher
# accuracy 0.9976013146386069
# f1 0.7537414965986394
# precision 0.9081967213114754 ,  recall 0.6441860465116279
# workload TP FP TN FN (277, 28, 75000, 153)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.998489225354451, 0.998327199732352]
# Disparity Values: [0.0008879107158440425, 0.000725885093745049]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# statistical_parity  Values: [0.003104558887007338, 0.0016728002676480427]
# Disparity Values: [-0.0005663573842959032, -0.001998116003655199]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [0.6900369003690037, 0.5660377358490566]
# Disparity Values: [0.04585085385737575, -0.07814831066257133]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0001167386555042276, 0.00039147698674570774]
# Disparity Values: [-0.0002564553520662794, 1.828297917520072e-05]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [0.9986009327115256, 0.9987148684137006]
# Disparity Values: [0.0006367795839059553, 0.0007507152860809496]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (187, 7, 59956, 84)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (90, 21, 53622, 69)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [0.9639175257731959, 0.8108108108108109]
# Disparity Values: [0.05572080446172045, -0.09738591050066459]
# ---------------------
# -------------------------------------------------
# Model: MCAN
# accuracy 0.9967001510774206
# f1 0.6041335453100158
# precision 0.9547738693467337 ,  recall 0.4418604651162791
# workload TP FP TN FN (190, 9, 75019, 240)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.9975429159610851, 0.998122746366306]
# Disparity Values: [0.0008427648836645263, 0.001422595288885442]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# statistical_parity  Values: [0.00212504565527775, 0.001152373517713096]
# Disparity Values: [-0.0003929113539194195, -0.0013655834914840733]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [0.47232472324723246, 0.389937106918239]
# Disparity Values: [0.03046425813095338, -0.05192335819804006]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [8.338475393159115e-05, 7.456704509442053e-05]
# Disparity Values: [-3.657046278750039e-05, -4.538817162467101e-05]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [0.9976206718690205, 0.9981948786660712]
# Disparity Values: [0.0008096592326580776, 0.0013838660297087468]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (128, 5, 59958, 143)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (62, 4, 53639, 97)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [0.9624060150375939, 0.9393939393939394]
# Disparity Values: [0.007632145690860237, -0.015379929952794247]
# ---------------------
# -------------------------------------------------
# Model: svm
# accuracy 0.9999602427840653
# f1 0.996523754345307
# precision 0.9930715935334873 ,  recall 1.0
# workload TP FP TN FN (430, 3, 75025, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.9999667961616363, 0.9999814133303595]
# Disparity Values: [6.553377571050234e-06, 2.117054629424686e-05]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [3.335390157263646e-05, 1.8641761273605132e-05]
# Disparity Values: [-6.631170667060723e-06, -2.1343310966092048e-05]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 2, 59961, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 1, 53642, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [0.9926739926739927, 0.99375]
# Disparity Values: [-0.00039760085949458457, 0.0006784064665127376]
# ---------------------
# -------------------------------------------------
# Model: rf
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Model: nb
# accuracy 0.9997747091097035
# f1 0.9806157354618017
# precision 0.9619686800894854 ,  recall 1.0
# workload TP FP TN FN (430, 17, 75011, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.9998007769698177, 0.9999070666517973]
# Disparity Values: [2.6067860114276087e-05, 0.00013235754209384165]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.00020012340943581877, 9.320880636802565e-05]
# Disparity Values: [-2.645866658913191e-05, -0.00013337326965692504]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 12, 59951, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 5, 53638, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [0.9575971731448764, 0.9695121951219512]
# Disparity Values: [-0.004371506944609083, 0.007543515032465753]
# ---------------------
# -------------------------------------------------
# Model: lg
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Model: ln
# accuracy 0.9994301465716028
# f1 0.9523809523809523
# precision 0.9090909090909091 ,  recall 1.0
# workload TP FP TN FN (430, 43, 74985, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [0.9994521366669987, 0.9996468532768299]
# Disparity Values: [2.1990095395940656e-05, 0.00021670670522710989]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0005503393759485016, 0.0003541934641984975]
# Disparity Values: [-2.2779992820491407e-05, -0.00021892590457049546]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 33, 59930, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 19, 53624, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [0.8914473684210527, 0.8932584269662921]
# Disparity Values: [-0.017643540669856406, -0.015832482124616964]
# ---------------------
# -------------------------------------------------
# Model: dt
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# measure accuracy_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# accuracy_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure statistical_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# statistical_parity  Values: [0.004499120098283361, 0.0029552804728448755]
# Disparity Values: [-0.0011994141856891795, -0.0027432538111276652]
# ---------------------
# measure true_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# true_positive_rate_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure false_positive_rate_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# false_positive_rate_parity  Values: [0.0, 0.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure negative_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# negative_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# measure positive_predictive_value_parity
# subgroup Caucasian
# TP, FP, TN, FN (271, 0, 59963, 0)
# No. of tuples 60234
#
# subgroup African-American
# TP, FP, TN, FN (159, 0, 53643, 0)
# No. of tuples 53802
#
# positive_predictive_value_parity  Values: [1.0, 1.0]
# Disparity Values: [0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Figure(1000x600)
# Model: DeepMatcher
# accuracy 0.9943014657160275
# f1 0.0
# /home/nima/fairER/Notebooks/venv/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# precision 0.0 ,  recall 0.0
# workload TP FP TN FN (0, 0, 75028, 430)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.9874861470262283, 0.9895559642669469, 1.0]
# Disparity Values: [-0.006815318689799232, -0.004745501449080591, 0.0056985342839724895]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.0, 0.0, 0.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [0.0, 0.0, 1]
# Disparity Values: [0.0, 0.0, 1.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0, 0.0, 0.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [0.9874861470262283, 0.9895559642669469, 1.0]
# Disparity Values: [-0.006815318689799232, -0.004745501449080591, 0.0056985342839724895]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (0, 0, 21385, 271)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (0, 0, 15065, 159)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [1, 1, 1]
# Disparity Values: [0, 0, 0]
# ---------------------
# -------------------------------------------------
# Model: HierMatcher
# accuracy 0.9976013146386069
# f1 0.7537414965986394
# precision 0.9081967213114754 ,  recall 0.6441860465116279
# workload TP FP TN FN (277, 28, 75000, 153)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.9957979312892501, 0.994088281660536, 1.0]
# Disparity Values: [-0.001803383349356813, -0.003513032978070929, 0.0023986853613930936]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.008635020317694865, 0.0059117183394640045, 0.0]
# Disparity Values: [0.004964104046391624, 0.002240802068160763, -0.0036709162713032414]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [0.6900369003690037, 0.5660377358490566, 1]
# Disparity Values: [0.04585085385737575, -0.07814831066257133, 0.3558139534883721]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0003273322422258593, 0.0013939595087952208, 0.0]
# Disparity Values: [-4.586176534464775e-05, 0.0010207655012247137, -0.000373194007570507]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [0.9960861056751468, 0.995434394230133, 1.0]
# Disparity Values: [-0.0018780474524728863, -0.0025297588974866336, 0.0020358468723803425]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (187, 7, 21378, 84)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (90, 21, 15044, 69)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [0.9639175257731959, 0.8108108108108109, 1]
# Disparity Values: [0.05572080446172045, -0.09738591050066459, 0.09180327868852456]
# ---------------------
# -------------------------------------------------
# Model: MCAN
# accuracy 0.9967001510774206
# f1 0.6041335453100158
# precision 0.9547738693467337 ,  recall 0.4418604651162791
# workload TP FP TN FN (190, 9, 75019, 240)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.9931658662726265, 0.9933657383079348, 1.0]
# Disparity Values: [-0.003534284804794119, -0.0033344127694857617, 0.003299848922579396]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.005910602142593277, 0.004072517078297425, 0.0]
# Disparity Values: [0.003392645133396107, 0.0015545600691002559, -0.0025179570091971694]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [0.47232472324723246, 0.389937106918239, 1]
# Disparity Values: [0.03046425813095338, -0.05192335819804006, 0.5581395348837209]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.00023380874444704232, 0.00026551609691337537, 0.0]
# Disparity Values: [0.00011385352772795078, 0.00014556088019428381, -0.00011995521671909154]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [0.9933559448032337, 0.9936007388837578, 1.0]
# Disparity Values: [-0.0034550678331286555, -0.003210273752604631, 0.0031889873636375965]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (128, 5, 21380, 143)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (62, 4, 15061, 97)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [0.9624060150375939, 0.9393939393939394, 1]
# Disparity Values: [0.007632145690860237, -0.015379929952794247, 0.045226130653266305]
# ---------------------
# -------------------------------------------------
# Model: svm
# accuracy 0.9999602427840653
# f1 0.996523754345307
# precision 0.9930715935334873 ,  recall 1.0
# workload TP FP TN FN (430, 3, 75025, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.999907646841522, 0.9999343142406726, 1.0]
# Disparity Values: [-5.259594254325428e-05, -2.5928543392672587e-05, 3.9757215934743684e-05]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [9.352349777881692e-05, 6.637902422834384e-05, 0.0]
# Disparity Values: [5.3538425539119744e-05, 2.6393951988646662e-05, -3.998507223969718e-05]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 2, 21383, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 1, 15064, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [0.9926739926739927, 0.99375, 1]
# Disparity Values: [-0.00039760085949458457, 0.0006784064665127376, 0.006928406466512715]
# ---------------------
# -------------------------------------------------
# Model: rf
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0, 0.0, 0.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Model: nb
# accuracy 0.9997747091097035
# f1 0.9806157354618017
# precision 0.9619686800894854 ,  recall 1.0
# workload TP FP TN FN (430, 17, 75011, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.9994458810491319, 0.9996715712033631, 1.0]
# Disparity Values: [-0.000328828060571551, -0.0001031379063403115, 0.0002252908902965478]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0005611409866729016, 0.00033189512114171923, 0.0]
# Disparity Values: [0.0003345589106479509, 0.00010531304511676856, -0.00022658207602495068]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 12, 21373, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 5, 15060, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [0.9575971731448764, 0.9695121951219512, 1]
# Disparity Values: [-0.004371506944609083, 0.007543515032465753, 0.03803131991051456]
# ---------------------
# -------------------------------------------------
# Model: lg
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0, 0.0, 0.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Model: ln
# accuracy 0.9994301465716028
# f1 0.9523809523809523
# precision 0.9090909090909091 ,  recall 1.0
# workload TP FP TN FN (430, 43, 74985, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [0.9988917620982638, 0.9993431424067262, 0.9997667064129815]
# Disparity Values: [-0.000538384473338982, -8.7004164876614e-05, 0.000336559841378703]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0011222819733458032, 0.0006637902422834385, 0.00023329358701850797]
# Disparity Values: [0.0005491626045768102, 9.067087351444551e-05, -0.00033982578175048496]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 24, 21361, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 10, 15055, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 9, 38569, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [0.9186440677966101, 0.9408284023668639, 0.0]
# Disparity Values: [0.00955315870570106, 0.031737493275954876, -0.9090909090909091]
# ---------------------
# -------------------------------------------------
# Model: dt
# accuracy 1.0
# f1 1.0
# precision 1.0 ,  recall 1.0
# workload TP FP TN FN (430, 0, 75028, 0)
#
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# accuracy_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# statistical_parity  Values: [0.012513852973771703, 0.010444035733053074, 0.0]
# Disparity Values: [0.006815318689799162, 0.004745501449080533, -0.005698534283972541]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# true_positive_rate_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# false_positive_rate_parity  Values: [0.0, 0.0, 0.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# negative_predictive_value_parity  Values: [1.0, 1.0, 1.0]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# subgroup Caucasian|Caucasian
# TP, FP, TN, FN (271, 0, 21385, 0)
# No. of tuples 21656
#
# subgroup African-American|African-American
# TP, FP, TN, FN (159, 0, 15065, 0)
# No. of tuples 15224
#
# subgroup African-American|Caucasian
# TP, FP, TN, FN (0, 0, 38578, 0)
# No. of tuples 38578
#
# positive_predictive_value_parity  Values: [1.0, 1.0, 1]
# Disparity Values: [0.0, 0.0, 0.0]
# ---------------------
# -------------------------------------------------
# Figure(1000x600)

# %%
import os
from IPython.display import display, Image
from math import ceil

def show_png_files(directory):
    png_files = [file for file in os.listdir(directory) if file.endswith('.png')]
    total_images = len(png_files)
    rows = ceil(total_images / 2)
    
    for i in range(rows):
        row_images = png_files[i*3: (i+1)*3]
        for image_file in row_images:
            display(Image(os.path.join(directory, image_file)))
        display("")

# %% [markdown]
# ## Compas Results

# %%
directory_path = './experiments/Compas/'
show_png_files(directory_path)
# Out:
# ''
